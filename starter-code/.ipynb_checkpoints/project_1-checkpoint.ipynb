# %% [markdown]
# # Project 1
#
# ## Step 1: Open the `sat_scores.csv` file. Investigate the data, and answer the questions below.

# %% [markdown]
# ##### 1. What does the data describe?

# %% [markdown]
# Data describes participation rate of the students and average scores in verbal and math in SAT per state in USA.

# %% [markdown]
# ##### 2. Does the data look complete? Are there any obvious issues with the observations?

# %% [markdown]
# Number of participants by state or total participants is not given in the data set

# %% [markdown]
# ##### 3. Create a data dictionary for the dataset.

# %%
import pandas as pd
df = pd.read_csv('../assets/sat_scores.csv')

# print df.head()
# print df.columns.values

dicty = df.to_dict()

# %% [markdown]
# ## Step 2: Load the data.

# %% [markdown]
# ##### 4. Load the data into a list of lists

# %%
lst = df.values.tolist()

# %% [markdown]
# ##### 5. Print the data

# %%
print df.columns.values
print df.head()


# print lst
# print dicty
# Out:
# ['State' 'Rate' 'Verbal' 'Math']
#   State  Rate  Verbal  Math
# 0    CT    82     509   510
# 1    NJ    81     499   513
# 2    MA    79     511   515
# 3    NY    77     495   505
# 4    NH    72     520   516

# %% [markdown]
# ##### 6. Extract a list of the labels from the data, and remove them from the data.

# %%
labels = df.columns.tolist()
print labels
# Out:
# ['State', 'Rate', 'Verbal', 'Math']

# %% [markdown]
# ##### 7. Create a list of State names extracted from the data. (Hint: use the list of labels to index on the State column)

# %%
states = [v for k,v in dicty['State'].items()]
print states
# Out:
# ['CT', 'NJ', 'MA', 'NY', 'NH', 'RI', 'PA', 'VT', 'ME', 'VA', 'DE', 'MD', 'NC', 'GA', 'IN', 'SC', 'DC', 'OR', 'FL', 'WA', 'TX', 'HI', 'AK', 'CA', 'AZ', 'NV', 'CO', 'OH', 'MT', 'WV', 'ID', 'TN', 'NM', 'IL', 'KY', 'WY', 'MI', 'MN', 'KS', 'AL', 'NE', 'OK', 'MO', 'LA', 'WI', 'AR', 'UT', 'IA', 'SD', 'ND', 'MS', 'All']

# %% [markdown]
# ##### 8. Print the types of each column

# %%
for col in df.columns.values: 
    print type(df[col][0])
# Out:
# <type 'str'>
# <type 'numpy.int64'>
# <type 'numpy.int64'>
# <type 'numpy.int64'>

# %% [markdown]
# ##### 9. Do any types need to be reassigned? If so, go ahead and do it.

# %%
Not required

# %% [markdown]
# ##### 10. Create a dictionary for each column mapping the State to its respective value for that column.

# %%
state_Dict = {}

for i, row in df.iterrows():
    state_Dict[df.State[i]] = {"Rate" : df.Rate[i], "Verbal" :df.Verbal[i], "Math" : df.Math[i]}

print state_Dict
# Out:
# {'WA': {'Rate': 53, 'Math': 527, 'Verbal': 527}, 'DE': {'Rate': 67, 'Math': 499, 'Verbal': 501}, 'DC': {'Rate': 56, 'Math': 474, 'Verbal': 482}, 'WI': {'Rate': 6, 'Math': 596, 'Verbal': 584}, 'WV': {'Rate': 18, 'Math': 512, 'Verbal': 527}, 'HI': {'Rate': 52, 'Math': 515, 'Verbal': 485}, 'FL': {'Rate': 54, 'Math': 499, 'Verbal': 498}, 'WY': {'Rate': 11, 'Math': 545, 'Verbal': 547}, 'NH': {'Rate': 72, 'Math': 516, 'Verbal': 520}, 'NJ': {'Rate': 81, 'Math': 513, 'Verbal': 499}, 'NM': {'Rate': 13, 'Math': 542, 'Verbal': 551}, 'TX': {'Rate': 53, 'Math': 499, 'Verbal': 493}, 'LA': {'Rate': 7, 'Math': 562, 'Verbal': 564}, 'NC': {'Rate': 65, 'Math': 499, 'Verbal': 493}, 'ND': {'Rate': 4, 'Math': 599, 'Verbal': 592}, 'NE': {'Rate': 8, 'Math': 568, 'Verbal': 562}, 'TN': {'Rate': 13, 'Math': 553, 'Verbal': 562}, 'NY': {'Rate': 77, 'Math': 505, 'Verbal': 495}, 'PA': {'Rate': 71, 'Math': 499, 'Verbal': 500}, 'RI': {'Rate': 71, 'Math': 499, 'Verbal': 501}, 'NV': {'Rate': 33, 'Math': 515, 'Verbal':
# ...

# %% [markdown]
# ##### 11. Create a dictionary with the values for each of the numeric columns

# %%
dfnum = df._get_numeric_data()

Num_Dict = {}
for col in dfnum.columns.values:
        Num_Dict[col] = df[col]

# print Num_Dict

# %% [markdown]
# ## Step 3: Describe the data

# %% [markdown]
# ##### 12. Print the min and max of each column

# %%
for col in dfnum.columns.values:
    print "min", col,  ":" , min(dfnum[col])
    print "max", col,  ":" , max(dfnum[col])
# Out:
# min Rate : 4
# max Rate : 82
# min Verbal : 482
# max Verbal : 593
# min Math : 439
# max Math : 603

# %% [markdown]
# ##### 13. Write a function using only list comprehensions, no loops, to compute Standard Deviation. Print the Standard Deviation of each numeric column.

# %%
import math
# funtion for standard deviation
def std(inp):
    std = math.sqrt(sum((inp[0:len(inp)] - float(sum(inp))/float(len(inp)))**2)/len(inp))
    return std 

for col in dfnum.columns.values:
    print "Standard Deviation of", col,  ":" , std(dfnum[col])
# Out:
# Standard Deviation of Rate : 27.0379964945
# Standard Deviation of Verbal : 32.9150949616
# Standard Deviation of Math : 35.6669961643

# %% [markdown]
# ## Step 4: Visualize the data

# %% [markdown]
# ##### 14. Using MatPlotLib and PyPlot, plot the distribution of the Rate using histograms.

# %%
import plotly.tools as tls
tls.set_credentials_file(username='shetty83', api_key='hwz8wwo6lh')

import matplotlib.pyplot as plt
import numpy as np

import plotly.plotly as py
# %matplotlib inline

plt.hist(df.Rate)
plt.title("Distribution of Application Rate")
plt.xlabel("Value")
plt.ylabel("Frequency")

# %% [markdown]
# ##### 15. Plot the Math distribution

# %%
plt.hist(df.Math)
plt.title("Distribution of Math Score")
plt.xlabel("Value")
plt.ylabel("Frequency")

# %% [markdown]
# ##### 16. Plot the Verbal distribution

# %%
plt.hist(df.Verbal)
plt.title("Distribution of Verbal Score")
plt.xlabel("Value")
plt.ylabel("Frequency")

# %% [markdown]
# ##### 17. What is the typical assumption for data distribution?

# %% [markdown]
# Typical assumption is that the data set is normally distributed

# %% [markdown]
# ##### 18. Does that distribution hold true for our data?

# %% [markdown]
# No, the average SAT score data set is not normally distributed

# %% [markdown]
# ##### 19. Plot some scatterplots. **BONUS**: Use a PyPlot `figure` to present multiple plots at once.

# %%
# list(df.Rate)
plt.scatter(df.Rate,df.Verbal, c=[1,0,0],s=80, alpha = 0.5)
plt.title("Rate vs Verbal Score for SAT", fontsize = 15)
plt.xlabel('Participation Rate')
plt.ylabel('Avg Verbal Score')
plt.show()
plt.scatter(df.Rate,df.Math, c=[0,0,1],s=80, alpha = 0.5)
plt.title("Rate vs Math Score for SAT", fontsize = 15)
plt.xlabel('Participation Rate')
plt.ylabel('Avg Math Score')
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.scatter(df.Rate,df.Verbal, c=[1,0,0], s=80, alpha = 0.5)
plt.scatter(df.Rate,df.Math, c=[0,0,1], alpha = 0.5, s=80)
plt.title("Rate vs Score's for SAT", fontsize = 20)
plt.xlabel('Participation Rate')
plt.ylabel('Avg Math and Verbal Score')
plt.show()

# %%
import seaborn as sns

sns.pairplot(df, size=3, kind ='reg')

# %% [markdown]
# ##### 20. Are there any interesting relationships to note?

# %% [markdown]
# As the participation rate increases, math and verbal scores decreases.
# ie Negative correlation is seen

# %% [markdown]
# ##### 21. Create box plots for each variable.

# %%
plt.boxplot(df.Rate)
plt.title("Participation Rate")
plt.show()
plt.boxplot([df.Verbal,df.Math])
plt.title("Verbal Score and Math Score")
plt.show()

# %% [markdown]
# ##### BONUS: Using Tableau, create a heat map for each variable using a map of the US.
